# %%
# This is just a sample Python script that prints "Hello, World!" to the console.

print("Hello, World!")
# Out:
# Hello, World!

# %% [markdown]
# # Markdown Language Tag Examples
#
# Use fenced code blocks with a language tag right after the opening backticks.
#
# ## Bash
# ```bash
# npm install dotenv
# ```
#
# ## Dotenv / Env file
# ```env
# NODE_ENV=development
# PORT=3000
# DATABASE_URL=postgres://localhost:5432/app
# ```
#
# ## TypeScript
# ```ts
# import dotenv from "dotenv";
#
# dotenv.config();
# console.log(process.env.PORT);
# ```
#
# ## JavaScript
# ```js
# require("dotenv").config();
# console.log(process.env.NODE_ENV);
# ```
#
# ## JSON
# ```json
# {
#   "scripts": {
#     "start": "node index.js"
#   }
# }
# ```
#
# ## YAML
# ```yaml
# env:
#   NODE_ENV: development
#   PORT: 3000
# ```
